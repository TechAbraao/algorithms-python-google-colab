# %% [markdown]
# <a href="https://colab.research.google.com/github/TechAbraao/algorithms-python-google-colab/blob/main/pandas_lib/barplot_com_seaborn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import seaborn as sns

# %%
# Criando um DataFrame
dataColumns = ["id", "data", "produto", "valor", "metodo_pagamento"]
data = [
    [2720, "2023-07-01", "Risoto de Funghi", 13.0, "Débito"],
    [2721, "2023-07-02", "Tiramisú", 10.0, "Débito"],
    [2722, "2023-07-02", "Tiramisú", 10.0, "Crédito"],
    [2723, "2023-07-02", "Ratatouille", 8.5, "PIX"],
    [2724, "2023-07-03", "Ratatouille", 8.5, "Dinheiro"],
    [2725, "2023-07-04", "Espaguete ao Alho e Óleo", 12.0, "Débito"],
    [2726, "2023-07-04", "Salada Mediterrânea", 7.5, "Crédito"],
    [2727, "2023-07-05", "Panna Cotta", 9.5, "Dinheiro"],
    [2728, "2023-07-05", "Pizza Margherita", 14.0, "PIX"],
    [2729, "2023-07-06", "Lasanha à Bolonhesa", 16.0, "Débito"],
    [2730, "2023-07-06", "Gnocchi de Batata", 11.0, "Crédito"],
    [2731, "2023-07-07", "Ravioli de Queijo", 13.5, "PIX"],
    [2732, "2023-07-07", "Focaccia", 6.0, "Dinheiro"],
    [2733, "2023-07-08", "Risoto de Camarão", 18.0, "Débito"],
    [2734, "2023-07-08", "Mousse de Chocolate", 9.0, "Crédito"]
]
df = pd.DataFrame(data, columns = dataColumns)
df
# Out:
#       id        data                   produto  valor metodo_pagamento
# 0   2720  2023-07-01          Risoto de Funghi   13.0           Débito
# 1   2721  2023-07-02                  Tiramisú   10.0           Débito
# 2   2722  2023-07-02                  Tiramisú   10.0          Crédito
# 3   2723  2023-07-02               Ratatouille    8.5              PIX
# 4   2724  2023-07-03               Ratatouille    8.5         Dinheiro
# 5   2725  2023-07-04  Espaguete ao Alho e Óleo   12.0           Débito
# 6   2726  2023-07-04       Salada Mediterrânea    7.5          Crédito
# 7   2727  2023-07-05               Panna Cotta    9.5         Dinheiro
# 8   2728  2023-07-05          Pizza Margherita   14.0              PIX
# 9   2729  2023-07-06       Lasanha à Bolonhesa   16.0           Débito
# 10  2730  2023-07-06         Gnocchi de Batata   11.0          Crédito
# 11  2731  2023-07-07         Ravioli de Queijo   13.5              PIX
# ...

# %%
# Criando o gráfico
quantidadePagamentos = df["metodo_pagamento"].value_counts().reset_index()
quantidadePagamentos.columns = ["Método de Pagamento", "Quantidade"]
sns.barplot(x="Método de Pagamento", y="Quantidade", data = quantidadePagamentos)
# Out:
# <Axes: xlabel='Método de Pagamento', ylabel='Quantidade'>
